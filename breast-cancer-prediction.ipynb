# %% [markdown]
# <h1 style='color:#9b006e; font-size:200%'> Importing Libraries and Dataset </h1>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.metrics import roc_curve, auc

from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv("breast-cancer.csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
#  14  perimeter_se             569 non-null    float64
#  15  area_se                  569 non-null    float64
#  16  smoothness_se            569 non-null    float64
#  17  compactness_se           569 non-null    float64
#  18  concavity_se             569 non-null    float64
#  19  concave points_se        569 non-null    float64
#  20  symmetry_se              569 non-null    float64
#  21  fractal_dimension_se     569 non-null    float64
#  22  radius_worst             569 non-null    float64
#  23  texture_worst            569 non-null    float64
#  24  perimeter_worst          569 non-null    float64
#  25  area_worst               569 non-null    float64
#  26  smoothness_worst         569 non-null    float64
#  27  compactness_worst        569 non-null    float64
#  28  concavity_worst          569 non-null    float64
#  29  concave points_worst     569 non-null    float64
#  30  symmetry_worst           569 non-null    float64
#  31  fractal_dimension_worst  569 non-null    float64
# dtypes: float64(30), int64(1), object(1)
# memory usage: 142.4+ KB

# %%
print(f"Total missing values      : {df.isnull().sum().sum()}")
print(f"total number of duplicate rows : {df.duplicated().sum()}")
# Out:
# Total missing values      : 0
# total number of duplicate rows : 0

# %%
df = df.drop("id", axis=1)

# %%
df.describe()
# Out:
#         diagnosis   radius_mean  texture_mean  perimeter_mean     area_mean  \
# count  569.000000  5.690000e+02  5.690000e+02    5.690000e+02  5.690000e+02
# mean     0.372583 -1.373633e-16  6.868164e-17   -1.248757e-16 -2.185325e-16
# std      0.483918  1.000880e+00  1.000880e+00    1.000880e+00  1.000880e+00
# min      0.000000 -2.029648e+00 -2.229249e+00   -1.984504e+00 -1.454443e+00
# 25%      0.000000 -6.893853e-01 -7.259631e-01   -6.919555e-01 -6.671955e-01
# 50%      0.000000 -2.150816e-01 -1.046362e-01   -2.359800e-01 -2.951869e-01
# 75%      1.000000  4.693926e-01  5.841756e-01    4.996769e-01  3.635073e-01
# max      1.000000  3.971288e+00  4.651889e+00    3.976130e+00  5.250529e+00
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count     5.690000e+02      5.690000e+02    5.690000e+02         5.690000e+02
# mean     -8.366672e-16      1.873136e-16    4.995028e-17        -4.995028e-17
# std       1.000880e+00      1.000880e+00    1.000880e+00         1.000880e+00
# min      -3.112085e+00     -1.610136e+00   -1.114873e+00        -1.261820e+00
# 25%      -7.109628e-01     -7.470860e-01   -7.437479e-01        -7.379438e-01
# 50%      -3.489108e-02     -2.219405e-01   -3.422399e-01        -3.977212e-01
# 75%       6.361990e-01      4.938569e-01    5.260619e-01         6.469351e-01
# max       4.770911e+00      4.568425e+00    4.243589e+00         3.927930e+00
#
#        symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# count   5.690000e+02  ...  5.690000e+02   5.690000e+02     5.690000e+02
# mean    1.748260e-16  ... -8.241796e-16   1.248757e-17    -3.746271e-16
# std     1.000880e+00  ...  1.000880e+00   1.000880e+00     1.000880e+00
# min    -2.744117e+00  ... -1.726901e+00  -2.223994e+00    -1.693361e+00
# 25%    -7.032397e-01  ... -6.749213e-01  -7.486293e-01    -6.895783e-01
# 50%    -7.162650e-02  ... -2.690395e-01  -4.351564e-02    -2.859802e-01
# 75%     5.307792e-01  ...  5.220158e-01   6.583411e-01     5.402790e-01
# max     4.484751e+00  ...  4.094189e+00   3.885905e+00     4.287337e+00
#
#        area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# count  569.000000      5.690000e+02       5.690000e+02     5.690000e+02
# mean     0.000000     -2.372638e-16      -3.371644e-16     7.492542e-17
# std      1.000880      1.000880e+00       1.000880e+00     1.000880e+00
# min     -1.222423     -2.682695e+00      -1.443878e+00    -1.305831e+00
# 25%     -0.642136     -6.912304e-01      -6.810833e-01    -7.565142e-01
# 50%     -0.341181     -4.684277e-02      -2.695009e-01    -2.182321e-01
# 75%      0.357589      5.975448e-01       5.396688e-01     5.311411e-01
# max      5.930172      3.955374e+00       5.112877e+00     4.700669e+00
#
#        concave points_worst  symmetry_worst  fractal_dimension_worst
# count          5.690000e+02    5.690000e+02             5.690000e+02
# mean           2.247763e-16    2.622390e-16            -5.744282e-16
# std            1.000880e+00    1.000880e+00             1.000880e+00
# min           -1.745063e+00   -2.160960e+00            -1.601839e+00
# 25%           -7.563999e-01   -6.418637e-01            -6.919118e-01
# 50%           -2.234689e-01   -1.274095e-01            -2.164441e-01
# 75%            7.125100e-01    4.501382e-01             4.507624e-01
# max            2.685877e+00    6.046041e+00             6.846856e+00
#
# [8 rows x 31 columns]

# %% [markdown]
# <h1 style='color:#9b006e; font-size:200%'> Distribution of malignant and benign tumors </h1>

# %%
cols = ["pink", "violet"]
plt.figure(figsize=(8,4))
plt.pie(x=df["diagnosis"].value_counts(), labels=df["diagnosis"].value_counts().index, shadow=True,
        explode=[0.02, 0.02], startangle=30, autopct='%0.2f%%', colors=cols)
plt.legend(labels=["Benign (non-cancerous)", "Malignant (cancerous)"], loc=(1,0.8), fontsize="small")
plt.suptitle("Rates of malignant and benign tumors", fontsize=14, color="b")
plt.tight_layout()
print(df.diagnosis.value_counts())
plt.show()
# Out:
# diagnosis
# 0    357
# 1    212
# Name: count, dtype: int64

# %%
# 1 for Malignant, 0 for Benign

df["diagnosis"] = df["diagnosis"].map({"B": 0, "M":1})

# %% [markdown]
# <h1 style='color:#9b006e; font-size:200%'> Correlation between features </h1>

# %%
corr = df.corr()
cmap = sns.diverging_palette(25, 250, as_cmap=True)
corr.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '1px', 'font-size': '8pt'})
# Out:
# <style type="text/css">
# #T_7f1d7_row0_col0, #T_7f1d7_row1_col1, #T_7f1d7_row1_col3, #T_7f1d7_row2_col2, #T_7f1d7_row3_col1, #T_7f1d7_row3_col3, #T_7f1d7_row4_col4, #T_7f1d7_row5_col5, #T_7f1d7_row6_col6, #T_7f1d7_row7_col7, #T_7f1d7_row8_col8, #T_7f1d7_row9_col9, #T_7f1d7_row10_col10, #T_7f1d7_row11_col11, #T_7f1d7_row12_col12, #T_7f1d7_row13_col13, #T_7f1d7_row14_col14, #T_7f1d7_row15_col15, #T_7f1d7_row16_col16, #T_7f1d7_row17_col17, #T_7f1d7_row18_col18, #T_7f1d7_row19_col19, #T_7f1d7_row20_col20, #T_7f1d7_row21_col21, #T_7f1d7_row22_col22, #T_7f1d7_row23_col23, #T_7f1d7_row24_col24, #T_7f1d7_row25_col25, #T_7f1d7_row26_col26, #T_7f1d7_row27_col27, #T_7f1d7_row28_col28, #T_7f1d7_row29_col29, #T_7f1d7_row30_col30 {
#   background-color: #4479bb;
#   color: #f1f1f1;
#   max-width: 1px;
#   font-size: 8pt;
# }
# #T_7f1d7_row0_col1, #T_7f1d7_row8_col27, #T_7f1d7_row17_col18 {
#   background-color: #9bb6d7;
#   color: #000000;
#   max-width: 1px;
#   font-size: 8pt;
# }
# #T_7f1d7_row0_col2, #T_7f1d7_row0_col29, #T_7f1d7_row8_col9, #T_7f1d7_row20_col15, #T_7f1d7_row22_col12 {
#   background-color: #ede3df;
#   color: #000000;
#   max-width: 1px;
#   font-size: 8pt;
# }
# #T_7f1d7_row0_col3, #T_7f1d7_row21_col13 {
#   background-color: #96b2d5;
#   color: #000000;
#   max-width: 1px;
#   font-size: 8pt;
# }
# #T_7f1d7_row0_col4 {
#   background-color: #a2bad9;
#   color: #000000;
#   max-width: 1px;
#   font-size: 8pt;
# }
# #T_7f1d7_row0_col5, #T_7f1d7_row2_col21, #T_7f1d7_row18_col26, #T_7f1d7_row23_col29 {
#   background-color: #e7d4cd;
#   color: #000000;
#   max-width: 1px;
#   font-size: 8pt;
# }
# #T_7f1d7_row0_col6, #T_7f1d7_row1_col6, #T_7f1d7_row6_col18, #T_7f1d7_row10_col25, #T_7f1d7_row17_col27 {
#   background-color: #c7d4e5;
#   color: #000000;
#   max-width: 1px;
#   font-size: 8pt;
# }
# #T_7f1d7_row0_col7, #T_7f1d7_row11_col21, #T_7f1d7_row13_col4, #T_7f1d7_row14_col8 {
#   background-color: #a6bdda;
#   color: #000000;
#   max-width: 1px;
#   font-size: 8pt;
# }
# #T_7f1d7_row0_col8, #T_7f1d7_row0_col21, #T_7f1d7_row4_col11 {
#   background-color: #8cabd2;
#   color: #f1f1f1;
#   max-width: 1px;
#   font-size: 8pt;
# }
# #T_7f1d7_row0_col9, #T_7f1d7_row2_col1, #T_7f1d7_row3_col5, #T_7f1d7_row5_col0, #T_7f1d7_row10_col28, #T_7f1d7_row21_col5, #T_7f1d7_row23_col5, #T_7f1d7_row23_col25 {
#   background-color: #e4ccc3;
#   color: #000000;
#   max-width: 1px;
#   font-size: 8pt;
# }
# #T_7f1d7_row0_col10, #T_7f1d7_row2_col5, #T_7f1d7_row11_col30, #T_7f1d7_row12_col25, #T_7f1d7_row13_col30, #T_7f1d7_row17_col2, #T_7f1d7_row19_col4, #T_7f1d7_row30_col1, #T_7f1d7_row30_col4 {
#   background-color: #be6b4b;
#   color: #f1f1f1;
#   max-width: 1px;
#   font-size: 8pt;
# }
# #T_7f1d7_row0_col11, #T_7f1d7_row5_col10, #T_7f1d7_row25_col6, #T_7f1d7_row28_col25 {
#   background-color: #d0dae8;
#   color: #000000;
#   max-width: 1px;
#   font-size: 8pt;
# }
# #T_7f1d7_row0_col12, #T_7f1d7_row0_col19, #T_7f1d7_row5_col22, #T_7f1d7_row12_col4, #T_7f1d7_row16_col2, #T_7f1d7_row25_col19 {
#   background-color: #be6e4e;
#   color: #f1f1f1;
#   max-width: 1px;
#   font-size: 8pt;
# }
# #T_7f1d7_row0_col13, #T_7f1d7_row6_col9, #T_7f1d7_row7_col14, #T_7f1d7_row14_col0, #T_7f1d7_row29_col27 {
#   background-color: #d4dde9;
#   color: #000000;
#   max-width: 1px;
#   font-size: 8pt;
# }
# #T_7f1d7_row0_col14, #T_7f1d7_row6_col0, #T_7f1d7_row10_col17, #T_7f1d7_row14_col28 {
#   background-color: #d7dfea;
#   color: #000000;
#   max-width: 1px;
#   font-size: 8pt;
# }
# #T_7f1d7_row0_col15, #T_7f1d7_row1_col10, #T_7f1d7_row2_col10, #T_7f1d7_row3_col10, #T_7f1d7_row4_col10, #T_7f1d7_row5_col2, #T_7f1d7_row6_col12, #T_7f1d7_row7_col12, #T_7f1d7_row8_col12, #T_7f1d7_row9_col2, #T_7f1d7_row10_col1, #T_7f1d7_row11_col10, #T_7f1d7_row12_col29, #T_7f1d7_row13_col10, #T_7f1d7_row14_col10, #T_7f1d7_row15_col21, #T_7f1d7_row16_col22, #T_7f1d7_row17_col22, #T_7f1d7_row18_col22, #T_7f1d7_row19_col21, #T_7f1d7_row20_col1, #T_7f1d7_row21_col10, #T_7f1d7_row22_col15, #T_7f1d7_row22_col19, #T_7f1d7_row23_col15, #T_7f1d7_row24_col10, #T_7f1d7_row25_col12, #T_7f1d7_row26_col12, #T_7f1d7_row27_col12, #T_7f1d7_row28_col12, #T_7f1d7_row29_col12, #T_7f1d7_row30_col12 {
#   background-color: #b85e39;
#   color: #f1f1f1;
#   max-width: 1px;
#   font-size: 8pt;
# }
# #T_7f1d7_row0_col16, #T_7f1d7_row4_col9, #T_7f1d7_row13_col17, #T_7f1d7_row15_col9, #T_7f1d7_row18_col23, #T_7f1d7_row22_col4, #T_7f1d7_row26_col2 {
#   background-color: #e0c1b6;
#   color: #000000;
#   max-width: 1px;
#   font-size: 8pt;
# }
# #T_7f1d7_row0_col17, #T_7f1d7_row5_col20, #T_7f1d7_row15_col6, #T_7f1d7_row18_col21, #T_7f1d7_row28_col20, #T_7f1d7_row29_col24 {
#   background-color: #dbb6a7;
#   color: #000000;
#   max-width: 1px;
#   font-size: 8pt;
# }
# #T_7f1d7_row0_col18, #T_7f1d7_row4_col22, #T_7f1d7_row15_col25, #T_7f1d7_row26_col4, #T_7f1d7_row26_col20 {
#   background-color: #ece1dc;
#   color: #000000;
#   max-width: 1px;
#   font-size: 8pt;
# }
# #T_7f1d7_row0_col20, #T_7f1d7_row15_col0, #T_7f1d7_row30_col21 {
#   background-color: #c8856a;
#   color: #f1f1f1;
#   max-width: 1px;
#   font-size: 8pt;
# }
# #T_7f1d7_row0_col22, #T_7f1d7_row21_col22, #T_7f1d7_row25_col8, #T_7f1d7_row28_col9 {
#   background-color: #f2eeee;
#   color: #000000;
#   max-width: 1px;
#   font-size: 8pt;
# }
# #T_7f1d7_row0_col23, #T_7f1d7_row1_col0, #T_7f1d7_row3_col0, #T_7f1d7_row24_col28, #T_7f1d7_row28_col3 {
#   background-color: #8aaad1;
#   color: #f1f1f1;
#   max-width: 1px;
#   font-size: 8pt;
# }
# #T_7f1d7_row0_col24, #T_7f1d7_row1_col7, #T_7f1d7_row1_col13, #T_7f1d7_row11_col24, #T_7f1d7_row18_col17, #T_7f1d7_row21_col7, #T_7f1d7_row28_col4 {
#   background-color: #99b4d6;
#   color: #000000;
#   max-width: 1px;
#   font-size: 8pt;
# }
# #T_7f1d7_row0_col25, #T_7f1d7_row7_col9, #T_7f1d7_row15_col5, #T_7f1d7_row19_col29, #T_7f1d7_row29_col19 {
#   background-color: #eee5e2;
#   color: #000000;
#   max-width: 1px;
#   font-size: 8pt;
# }
# #T_7f1d7_row0_col26, #T_7f1d7_row16_col7, #T_7f1d7_row23_col26 {
#   background-color: #c9d6e6;
#   color: #000000;
#   max-width: 1px;
#   font-size: 8pt;
# }
# #T_7f1d7_row0_col27, #T_7f1d7_row8_col14, #T_7f1d7_row10_col5, #T_7f1d7_row13_col3, #T_7f1d7_row27_col0 {
#   background-color: #b2c6de;
#   color: #000000;
#   max-width: 1px;
#   font-size: 8pt;
# }
# #T_7f1d7_row0_col28, #T_7f1d7_row1_col28, #T_7f1d7_row6_col27, #T_7f1d7_row6_col28, #T_7f1d7_row8_col24, #T_7f1d7_row21_col14 {
#   background-color: #86a7d0;
#   color: #f1f1f1;
#   max-width: 1px;
#   font-size: 8pt;
# }
# #T_7f1d7_row0_col30, #T_7f1d7_row10_col8, #T_7f1d7_row21_col16, #T_7f1d7_row23_col17 {
#   background-color: #e3c9c0;
#   color: #000000;
#   max-width: 1px;
#   font-size: 8pt;
# }
# #T_7f1d7_row1_col2, #T_7f1d7_row5_col26, #T_7f1d7_row6_col24, #T_7f1d7_row6_col29, #T_7f1d7_row16_col10, #T_7f1d7_row21_col18, #T_7f1d7_row25_col7, #T_7f1d7_row26_col24 {
#   background-color: #f1edec;
#   color: #000000;
#   max-width: 1px;
#   font-size: 8pt;
# }
# #T_7f1d7_row1_col4, #T_7f1d7_row3_col4, #T_7f1d7_row4_col1, #T_7f1d7_row4_col3 {
#   background-color: #477bbb;
#   color: #f1f1f1;
#   max-width: 1px;
#   font-size: 8pt;
# }
# #T_7f1d7_row1_col5, #T_7f1d7_row2_col4, #T_7f1d7_row28_col2 {
#   background-color: #e3cbc1;
#   color: #000000;
#   max-width: 1px;
#   font-size: 8pt;
# }
# #T_7f1d7_row1_col8, #T_7f1d7_row21_col8, #T_7f1d7_row27_col28 {
#   background-color: #7299c9;
#   color: #f1f1f1;
#   max-width: 1px;
#   font-size: 8pt;
# }
# #T_7f1d7_row1_col9, #T_7f1d7_row2_col27, #T_7f1d7_row18_col3, #T_7f1d7_row19_col13, #T_7f1d7_row21_col9, #T_7f1d7_row21_col17, #T_7f1d7_row22_col7, #T_7f1d7_row24_col16 {
#   background-color: #e1c5ba;
#   color: #000000;
#   max-width: 1px;
#   font-size: 8pt;
# }
# #T_7f1d7_row1_col11, #T_7f1d7_row3_col11, #T_7f1d7_row3_col13, #T_7f1d7_row4_col7, #T_7f1d7_row14_col1 {
#   background-color: #98b3d6;
#   color: #000000;
#   max-width: 1px;
#   font-size: 8pt;
# }
# #T_7f1d7_row1_col12, #T_7f1d7_row20_col14 {
#   background-color: #cb8d74;
#   color: #f1f1f1;
#   max-width: 1px;
#   font-size: 8pt;
# }
# #T_7f1d7_row1_col14, #T_7f1d7_row3_col14, #T_7f1d7_row24_col11 {
#   background-color: #89a9d1;
#   color: #f1f1f1;
#   max-width: 1px;
#   font-size: 8pt;
# }
# #T_7f1d7_row1_col15, #T_7f1d7_row22_col20 {
#   background-color: #c07152;
#   color: #f1f1f1;
#   max-width: 1px;
#   font-size: 8pt;
# }
# #T_7f1

# %% [markdown]
# <h1 style='color:#9b006e; font-size:200%'> Correlation between features and target variable </h1>

# %%
corr = df.corr()["diagnosis"].abs().sort_values(ascending=False).drop("diagnosis")

plt.figure(figsize=(8,6))
sns.barplot(x=corr, y=corr.index, color="orange")
plt.title("Correlation between features and target variable")
plt.yticks(fontsize= 8)
plt.xlabel("")
plt.show()

# %% [markdown]
# <h1 style='color:#9b006e; font-size:200%'> Standardization </h1>

# %%
scaler = StandardScaler()
df.iloc[:, 2:] = scaler.fit_transform(df.iloc[:, 2:])
df.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1     1.097064     -2.073335        1.269934   0.984375
# 1    842517          1     1.829821     -0.353632        1.685955   1.908708
# 2  84300903          1     1.579888      0.456187        1.566503   1.558884
# 3  84348301          1    -0.768909      0.253732       -0.592687  -0.764464
# 4  84358402          1     1.750297     -1.151816        1.776573   1.826229
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0         1.568466          3.283515        2.652874             2.532475
# 1        -0.826962         -0.487072       -0.023846             0.548144
# 2         0.942210          1.052926        1.363478             2.037231
# 3         3.283553          3.402909        1.915897             1.451707
# 4         0.280372          0.539340        1.371011             1.428493
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...      1.886690      -1.359293         2.303601    2.001237
# 1  ...      1.805927      -0.369203         1.535126    1.890489
# 2  ...      1.511870      -0.023974         1.347475    1.456285
# 3  ...     -0.281464       0.133984        -0.249939   -0.550021
# 4  ...      1.298575      -1.466770         1.338539    1.220724
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0          1.307686           2.616665         2.109526              2.296076
# 1         -0.375612          -0.430444        -0.146749              1.087084
# 2          0.527407           1.082932         0.854974              1.955000
# 3          3.394275           3.893397         1.989588              2.175786
# 4          0.220556          -0.313395         0.613179              0.729259
#
#    symmetry_worst  fractal_dimension_worst
# 0        2.750622                 1.937015
# 1       -0.243890                 0.281190
# 2        1.152255                 0.201391
# 3        6.046041                 4.935010
# 4       -0.868353                -0.397100
#
# [5 rows x 32 columns]

# %% [markdown]
# <h1 style='color:#9b006e; font-size:200%'> Train/Test Split </h1>

# %%
y = df["diagnosis"]
X = df.drop("diagnosis", axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %% [markdown]
# <h1 style='color:#9b006e; font-size:200%'> Creating and comparing models </h1>

# %%
model_list = [LogisticRegression, RandomForestClassifier, KNeighborsClassifier, SVC, XGBClassifier, DecisionTreeClassifier]

model_name_list = []
model_accuracies = []

for i in model_list:
    model = i().fit(X_train, y_train)
    model_name = model.__class__.__name__
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)

    model_name_list.append(model_name)
    model_accuracies.append(accuracy)

    print(f"{model_name} accuracy: {accuracy:.3f}\n")
# Out:
# LogisticRegression accuracy: 0.979
#
# RandomForestClassifier accuracy: 0.965
#
# KNeighborsClassifier accuracy: 0.958
#
# SVC accuracy: 0.972
#
# XGBClassifier accuracy: 0.958
#
# DecisionTreeClassifier accuracy: 0.951

# %%
fig, ax=plt.subplots(figsize=(7,5))
cols = ["violet" if i < (max(model_accuracies)) else "pink" for i in model_accuracies]
sns.barplot(x= model_name_list, y= model_accuracies, ax=ax, palette=cols)
plt.ylim(0.8, 1)
plt.title("Scores of Models", fontsize=15)
plt.axhline(0.9790, lw=0.9, ls="--", color="red")
plt.xticks(rotation=60)
print(f"LogisticRegression accuracy: {np.max(model_accuracies):.2f}")
plt.show()
# Out:
# LogisticRegression accuracy: 0.98

# %% [markdown]
# <h1 style='color:#9b006e; font-size:200%'> Model Tuning </h1>

# %%
logistic = LogisticRegression()

param_list = {"C": np.arange(0.0001, 1.01, 0.05),
             "penalty": ['l1', 'l2'],
             "solver": ['liblinear', 'lbfgs']}

model_tuning = GridSearchCV(estimator=logistic, param_grid=param_list, cv=10).fit(X_train, y_train)
y_pred_final = model_tuning.best_estimator_.predict(X_test)
accuracy_final = accuracy_score(y_test, y_pred_final)
print(f"Accuracy after tuning: {accuracy_final:.3f}")
# Out:
# Accuracy after tuning: 0.993

# %% [markdown]
# <h1 style='color:#9b006e; font-size:200%'> Accuracy after hyperparameter optimization </h1>

# %%
plt.figure(figsize=(7,5))
sns.barplot(x=["Before model tuning", "After model tuning"], y=[model_accuracies[0], accuracy_final],
            palette=["pink", "violet"])
plt.ylim(0.7, 1)
plt.axhline(accuracy_final, ls="--", lw=1, color="r")
plt.title("Accuracy after hyperparameter optimization\n")
plt.show()

# %% [markdown]
# <h1 style='color:#9b006e; font-size:200%'> Confusion matrix </h1>

# %%
plt.figure(figsize=(6,4))
sns.heatmap(confusion_matrix(y_test, y_pred_final), annot=True, cmap="RdPu",
            xticklabels=["Benign (non-cancerous)", "Malignant (cancerous)"])
plt.title("Confusion matrix of LogisticRegression", fontsize=15)
plt.show()

# %% [markdown]
# <h1 style='color:#9b006e; font-size:200%'> Classification report </h1>

# %%
print(classification_report(y_test, y_pred_final))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        89
#            1       1.00      0.98      0.99        54
#
#     accuracy                           0.99       143
#    macro avg       0.99      0.99      0.99       143
# weighted avg       0.99      0.99      0.99       143
